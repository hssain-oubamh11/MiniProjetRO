# %%
import core.batiment
print(dir(core.batiment))

# # Création du bâtiment
# bat = Batiment()

# # ----------------------------
# # AJOUT DES NOEUDS
# # ----------------------------

# bat.ajouter_salle("Salle_A", 30)
# bat.ajouter_salle("Salle_B", 20)

# bat.ajouter_couloir("Couloir_1", 50)

# bat.ajouter_escalier("Escalier", 40)

# bat.ajouter_sortie("Sortie_1", 100)
# bat.ajouter_sortie("Sortie_2", 80)

# # ----------------------------
# # AJOUT DES ARCS
# # ----------------------------

# bat.ajouter_arc("Salle_A", "Couloir_1", 20, 5, 10)

# bat.ajouter_arc("Salle_B", "Couloir_1", 15, 4, 8)

# bat.ajouter_arc("Couloir_1", "Escalier", 30, 3, 12)

# bat.ajouter_arc("Escalier", "Sortie_1", 40, 2, 6)

# bat.ajouter_arc("Salle_B", "Sortie_2", 10, 7, 15)

# # ----------------------------
# # TESTS
# # ----------------------------

# print("===== NOEUDS =====")
# print(bat.batiment.nodes(data=True))

# print("\n===== ARCS =====")
# print(bat.batiment.edges(data=True))

# print("\n===== SORTIES =====")
# print(bat.get_sorties())

# print("\n===== VOISINS Couloir_1 =====")
# print(bat.get_voisins("Couloir_1"))

# print("\n===== TEST FUMEE =====")

# bat.mettre_a_jour_fumee("Couloir_1", 60)

# print(
#     bat.batiment.nodes["Couloir_1"]
# )

# print("\n===== TEST BLOCAGE =====")

# print(
#     bat.est_arc_praticable(
#         "Salle_A",
#         "Couloir_1"
#     )
# )

# bat.bloquer_arc(
#     "Salle_A",
#     "Couloir_1"
# )

# print(
#     bat.est_arc_praticable(
#         "Salle_A",
#         "Couloir_1"
#     )
# )

# print(
#     bat.batiment.edges[
#         "Salle_A",
#         "Couloir_1"
#     ]
# )
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']
